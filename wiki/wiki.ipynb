# %% [markdown]
# ---
# layout: wiki
# title: Wiki
#
# ---
# ## Table of Contents
# 1. [Machine Learning](#ML)
# 2. [Machine Translation](#MT)
# 3. [Interesting Algorithms](#AL)
# 4. [MISC](#MI)
#
# ### Machine Learning<a name="ML"></a>
#
# - GD/SDG
# 	- [Gradient descent revisited][6]
# 	- [Stochastic Gradient Descent Tricks][7]
# <p></p>
#
# - Naive Bayes
# 	- [UW NB Tutorial][10]
# 	- [Text Classification and Naive Bayes][11]
# 	- [Beta-Binomial Model][16]
# <p></p>
#
# - Support Vector Machine
# 	- [Stanford CS229 SVM Note][5]
# 	- [An Idiot’s guide to Support vector
# machines (SVMs)][2]
# 	- [Lagrange Multipliers Tutorial in the Context
# of Support Vector Machines][1]
# <p></p>
#
# - Principle Component Analysis
# 	- [An Introduction to Principal Component Analysis][14]
# 	- [PCA Slides from Columbia statistics department][15]
# <p></p>
#
# - Latend Dirichlet Allocation
# 	- [Topic Model by David Blei (Vedio)][12]
# 	- [Original Paper][13]
# <p></p>
#
# - Hidden Markov Model
# 	- [The EM algorithm for HMMs, Michael Collins][17]
# 	- [HMM with Gaussian emission][24]
# <p><p/>
#
# - Variational Inference
# 	- [Tutorial By Blei][23]
# <p><p/>
#
# - Courses
# 	- [Coursera: Machine Learning][4]
# 	- [Stanford CS229][3]
# <p></p>
#
# ### Machine Translation<a name="MT"></a>
# **Note:**
#
# [Machine Translation Class][20], [mt-archive][21] and [moses homepage][22] are your best friend.
#
# - General
# 	- [Automating Knowledge Acquisition for Machine Translation][18]
# 	- [Translation status][19].
# 	<p></p>
#
# - Word Alignment
#
# - Decoding
#
# - Evaluator
#
# - Rerank
#
# - Phrase based Translation
#
# ### Interesting Algorithms <a name="AL"></a>
#
# - [Moore Voting][26]
# <p></p>
#
# ### MISC<a name="MI"></a>
# - Terminal
# 	- [oh-my-zsh][8]
# <p></p>
#
# - Scala
# 	- [Run Scala with Sublime Text3 and sbt][25]
# <p></p>
#
# - Rails
# 	- [Deploy Rails & AngularJS on Apache][27]
#
# [1]: http://www.engr.mun.ca/~baxter/Publications/LagrangeForSVMs.pdf
# [2]: http://www.cs.ucf.edu/courses/cap6412/fall2009/papers/Berwick2003.pdf
# [3]: http://cs229.stanford.edu/materials.html
# [4]: https://www.coursera.org/course/ml
# [5]: http://cs229.stanford.edu/notes/cs229-notes3.pdf
# [6]: https://www.cs.cmu.edu/~ggordon/10725-F12/slides/05-gd-revisited.pdf
# [7]: http://research.microsoft.com/pubs/192769/tricks-2012.pdf
# [8]: https://github.com/robbyrussell/oh-my-zsh
# [10]: https://courses.cs.washington.edu/courses/cse546/12wi/slides/cse546wi12naivebayes.pdf
# [11]: https://web.stanford.edu/class/cs124/lec/naivebayes.pdf
# [12]: http://videolectures.net/mlss09uk_blei_tm/
# [13]: http://www.jmlr.org/papers/volume3/blei03a/blei03a.pdf
# [14]: http://web.ipac.caltech.edu/staff/fmasci/home/statistics_refs/PrincipalComponentAnalysis.pdf
# [15]: http://www.stat.columbia.edu/~fwood/Teaching/w4315/Spring2010/PCA/slides.pdf
# [16]: http://www.cs.cmu.edu/~10701/lecture/technote2_betabinomial.pdf
# [17]: http://www.cs.columbia.edu/~mcollins/courses/6998-2012/lectures/lec6.3.pdf
# [18]: http://www.isi.edu/natural-language/mt/aimag97.pdf
# [19]: http://www.stanford.edu/~mjkay/CurrentState.pdf
# [20]: http://mt-class.org
# [21]: http://mt-archive.info/
# [22]: http://www.statmt.org/moses/
# [23]: https://www.cs.princeton.edu/courses/archive/fall11/cos597C/lectures/variational-inference-i.pdf
# [24]: http://personal.ee.surrey.ac.uk/Personal/P.Jackson/tutorial/hmm_tut4.pdf
# [25]: {{ site.url }}/2015/06/03/sublime-sbt
# [26]: http://www.cs.utexas.edu/~moore/best-ideas/mjrty/index.html
# [27]: {{ site.url }}/2015/06/29/rails-angularjs-apache
